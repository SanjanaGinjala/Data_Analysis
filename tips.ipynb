# %% [markdown]
# ## tips

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset("tips")

# %%
print("Shape:", df.shape)
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# Shape: (244, 7)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB
# None
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000
# ...

# %%
print(df.head(5))
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print("Duplicates:", df.duplicated().sum())

# No missing values, verify
print("Missing Values:\n", df.isnull().sum())

# Ensure categorical columns are properly typed
df['sex'] = df['sex'].astype('category')
df['smoker'] = df['smoker'].astype('category')
df['day'] = df['day'].astype('category')
df['time'] = df['time'].astype('category')
# Out:
# Duplicates: 1
# Missing Values:
#  total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
avg_tip = df.groupby('day')['tip'].mean()
print("\nAverage tip by day:\n", avg_tip)
# Out:
# Average tip by day:
#  day
# Thur    2.771452
# Fri     2.734737
# Sat     2.993103
# Sun     3.255132
# Name: tip, dtype: float64
# C:\Users\SANJANA\AppData\Local\Temp\ipykernel_7160\2260183366.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_tip = df.groupby('day')['tip'].mean()

# %% [markdown]
# ## Visualization - Matplotlib

# %%
plt.figure(figsize=(8,5))
plt.bar(avg_tip.index, avg_tip.values, color='skyblue')
plt.title("Average Tip by Day (Economy Proxy)")
plt.ylabel("Average Tip")
plt.show()

# %% [markdown]
# ## Visualization - Seaborn

# %%
plt.figure(figsize=(10,6))
sns.countplot(y='day', data=df, order=df['day'].value_counts().index)
plt.title("Number of Customers per Day")
plt.show()

# %% [markdown]
# ## Insights:
#
# ### Tips vary by day, indicating different spending patterns.
#
# ### Friday and Saturday have higher customer counts → peak economic activity.
